# %%
import pandas as pd

# %%
df = pd.read_csv("D:/EM_38/data/Venue_master.csv")

# %%
print(df.columns.tolist())
# Out:
# ['Name', 'Image_link', 'Location', 'Listing_type', 'Rating', 'Price', 'Description', 'Venue_space_type', 'City', 'Initial_price']
