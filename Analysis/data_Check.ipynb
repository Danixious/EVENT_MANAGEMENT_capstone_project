# %%
import pandas as pd

# %%
df = pd.read_csv("D:/EM_38/data/VenueLook2.csv")

# %%
df.shape
# Out:
# (3684, 10)

# %%
df.head(5)
# Out:
#                                            name  \
# 0                           Woodapple Residency
# 1                       Venizia Sarovar Portico
# 2  Luxera Hotels Banquets Convention & Catering
# 3                                  Tivoli Grand
# 4                          Calista Resort Delhi
#
#                                          bg_img_link                   mark  \
# 0  https://cdn.venuelook.com/uploads/space_2877/1...     Karkardooma, Delhi
# 1  https://cdn.venuelook.com/uploads/space_1824/1...      Model Town, Delhi
# 2  https://cdn.venuelook.com/uploads/space_25396/...         Mg Road, Delhi
# 3  https://cdn.venuelook.com/uploads/space_165/16...  Gt Karnal Road, Delhi
# 4  https://cdn.venuelook.com/uploads/space_9254/1...       Kapashera, Delhi
#
#         category  rating                    price  \
# 0  banquet-halls     4.8   Rs. 699 price per plat
# 1  banquet-halls     4.9  Rs. 1000 price per plat
# 2  banquet-halls     4.6  Rs. 1800 price per plat
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                               name  \
# 0                              Woodapple Residency
# 1                          Venizia Sarovar Portico
# 2     Luxera Hotels Banquets Convention & Catering
# 3                                     Tivoli Grand
# 4                             Calista Resort Delhi
# ...                                            ...
# 3679                            Event Corporations
# 3680                                  Giggle Event
# 3681                                        Regale
# 3682                          Ifd Wedding Planners
# 3683                                The Bliss Wish
#
#                                             bg_img_link  \
# 0     https://cdn.venuelook.com/uploads/space_2877/1...
# 1     https://cdn.venuelook.com/uploads/space_1824/1...
# 2     https://cdn.venuelook.com/uploads/space_25396/...
# 3     https://cdn.venuelook.com/uploads/space_165/16...
# ...

# %%
df.describe().round()
# Out:
#        rating  int_price
# count  3684.0     3684.0
# mean      3.0    18410.0
# std       1.0    61496.0
# min       0.0      199.0
# 25%       2.0      799.0
# 50%       3.0     1400.0
# 75%       4.0     2500.0
# max       5.0   650000.0

# %%
df.isnull().sum()
# Out:
# name           0
# bg_img_link    0
# mark           0
# category       0
# rating         0
# price          0
# address        0
# role           0
# city           0
# int_price      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

# %%
df = pd.read_csv("D:/EM_38/data/Venue_master.csv", encoding="latin1")  # load dataset
print("Original shape:", df.shape)
print(df["Listing_type"].unique())
# Out:
# Original shape: (3684, 10)
# ['banquet-halls' 'photographers' 'makeup-artists' 'decorators' 'dj'
#  'event-planners']

# %%
import pandas as pd
df = pd.read_csv("D:/EM_38/data/vendors_clean.csv")
df.columns.tolist()
# Out:
# ['vendor_id',
#  'Name',
#  'Image_link',
#  'Location',
#  'Listing_type',
#  'Rating',
#  'Price',
#  'Description',
#  'Venue_space_type',
#  'City',
#  'Initial_price']
