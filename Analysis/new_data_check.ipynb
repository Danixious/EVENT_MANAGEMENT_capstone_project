# %%
import pandas as pd

# %%
df = pd.read_csv("D:/EM_38/data/Venue_master.csv")

# %%
df.head(5)
# Out:
#                                            Name  \
# 0                           Woodapple Residency
# 1                       Venizia Sarovar Portico
# 2  Luxera Hotels Banquets Convention & Catering
# 3                                  Tivoli Grand
# 4                          Calista Resort Delhi
#
#                                           Image_link               Location  \
# 0  https://cdn.venuelook.com/uploads/space_2877/1...     Karkardooma, Delhi
# 1  https://cdn.venuelook.com/uploads/space_1824/1...      Model Town, Delhi
# 2  https://cdn.venuelook.com/uploads/space_25396/...         Mg Road, Delhi
# 3  https://cdn.venuelook.com/uploads/space_165/16...  Gt Karnal Road, Delhi
# 4  https://cdn.venuelook.com/uploads/space_9254/1...       Kapashera, Delhi
#
#     Listing_type  Rating                    Price  \
# 0  banquet-halls     4.8   Rs. 699 price per plat
# 1  banquet-halls     4.9  Rs. 1000 price per plat
# 2  banquet-halls     4.6  Rs. 1800 price per plat
# ...

# %%
df.isnull().sum()
# Out:
# Name                0
# Image_link          0
# Location            0
# Listing_type        0
# Rating              0
# Price               0
# Description         0
# Venue_space_type    0
# City                0
# Initial_price       0
# dtype: int64

# %%
df.shape
# Out:
# (3684, 10)

# %%
df1 =  pd.read_csv("D:/EM_38/data/venues_db_ready.csv")
df1.shape
# Out:
# (82, 10)

# %%
print(df["Listing_type"].value_counts())
# Out:
# Listing_type
# banquet-halls     1870
# photographers      518
# makeup-artists     463
# decorators         286
# dj                 278
# event-planners     269
# Name: count, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Image_link',
#  'Location',
#  'Listing_type',
#  'Rating',
#  'Price',
#  'Description',
#  'Venue_space_type',
#  'City',
#  'Initial_price']
